# %%
from clima import obtener_clima

# %%
obtener_clima(["Medellín"])
# Out:
# [{'municipio': 'Medellín',
#   'latitud': 6.25,
#   'longitud': -75.625,
#   'temperatura_c': 24.6,
#   'weather_code': 3,
#   'descripcion_clima': 'Nublado',
#   'ultima_actualizacion': '2026-03-02 21:22:07'}]
